# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\umar_\anaconda3\lib\site-packages (1.2.7)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'id.co.bitcoin',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=55000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_result = pd.DataFrame(np.array(result),columns=['review'])

df_result = df_result.join(pd.DataFrame(df_result.pop('review').tolist()))

df_result
# Out:
#                                    reviewId              userName  \
# 0      9c6863cf-0390-467c-8899-741375e562f6       Pengguna Google
# 1      394f16ba-7be1-4aa0-bdec-5d6be1e359bb       Pengguna Google
# 2      b234ca11-9cc0-4d86-81ad-fb44abff9e7e       Pengguna Google
# 3      5b28bc72-d4e5-43e3-b149-718ad6cb2349       Pengguna Google
# 4      1b84f25e-317c-4748-bc8b-fb2de4c20102       Pengguna Google
# ...                                     ...                   ...
# 54995  3eb93f99-6548-4ffd-9b6a-3aa363e8b61c      yahya dirgantara
# 54996  b63cfbb3-bfed-46c6-ab22-3ab1daa14e46              FERI EDP
# 54997  e3e8c64d-8c8f-48f5-a78b-5025abed31f8     Eko Tri Prasetiyo
# 54998  df5b782b-79fb-486c-b21a-09329bb4107b  Ywono mustikaningrat
# 54999  bb75381d-ecab-409b-965d-ea9269d4eca5                 WA TV
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 54995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      INDODAX 3.0 cocok banget buat pemula seperti s...      5
# 1      Aplikasi nya mudah diakses dan digunakan, terp...      5
# 2      Aplikasi Indodax sangat user-friendly, ideal u...      5
# 3      Tidak diragukan lagi, INDODAX adalah salah sat...      5
# 4      indodax aneh akun tiba² terkunci, pas pelapora...      1
# ...                                                  ...    ...
# 54995                                            Posting      5
# 54996                                               Good      5
# 54997                                           Sempurna      5
# 54998                                              Keren      5
# 54999                                               Good      5
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  9                5.4.8 2025-04-05 14:23:04
# 1                 94                5.4.8 2025-03-20 12:11:49
# 2                  9                5.4.8 2025-04-05 17:26:48
# 3                  1                5.4.8 2025-04-05 17:34:33
# 4                  3                5.4.8 2025-04-05 00:15:54
# ...              ...                  ...                 ...
# 54995              0                4.2.2 2021-11-27 16:34:27
# 54996              0                4.2.2 2021-11-20 17:32:48
# 54997              0                4.2.2 2021-11-06 20:26:24
# 54998              0                4.2.2 2021-10-27 14:41:48
# 54999              0                4.2.2 2021-11-24 23:46:59
#
#                                             replyContent           repliedAt  \
# 0      Dear member, terima kasih telah mengikuti even... 2025-04-05 14:26:08
# 1      Dear member INDODAX, terima kasih atas review ... 2025-03-20 12:55:39
# 2      Dear member, terima kasih telah mengikuti even... 2025-04-06 01:37:22
# 3      Dear member, terima kasih telah mengikuti even... 2025-04-06 01:37:30
# 4      Dear member INDODAX. Mohon maaf atas ketidakny... 2025-04-05 02:36:09
# ...                                                  ...                 ...
# 54995  Dear member Indodax. Terima kasih atas review ... 2021-11-27 20:09:20
# 54996  Dear Indodax members. Thank you for your revie... 2021-11-20 17:37:21
# 54997  Dear member Indodax. Terima kasih atas review ... 2021-11-06 20:36:57
# 54998  Dear member Indodax. Terima kasih atas review ... 2021-10-27 14:57:55
# 54999  Dear Indodax member. Thank you for your review... 2021-11-25 07:08:20
#
#       appVersion
# 0          5.4.8
# 1          5.4.8
# 2          5.4.8
# 3          5.4.8
# 4          5.4.8
# ...          ...
# 54995      4.2.2
# 54996      4.2.2
# 54997      4.2.2
# 54998      4.2.2
# 54999      4.2.2
#
# [55000 rows x 11 columns]

# %%
df_result.to_csv('data_scraping.csv', index=False)

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              55000 non-null  object
#  1   userName              55000 non-null  object
#  2   userImage             55000 non-null  object
#  3   content               55000 non-null  object
#  4   score                 55000 non-null  int64
#  5   thumbsUpCount         55000 non-null  int64
#  6   reviewCreatedVersion  42778 non-null  object
#  7   at                    55000 non-null  datetime64[ns]
#  8   replyContent          570 non-null    object
#  9   repliedAt             570 non-null    datetime64[ns]
#  10  appVersion            42778 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 4.6+ MB
